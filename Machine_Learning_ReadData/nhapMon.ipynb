# %% [markdown]
# ##  CHƯƠNG 2: QUY TRÌNH XÂY DỰNG MỘT HỆ THỐNG HỌC MÁY - PHẦN 1
# -----
#
# **NỘI DUNG BÀI HỌC:**
# 1. Đọc dữ liệu từ file CSV, Text
# 2. Đọc dữ liệu từ file Excel
# 3. Tải dữ liệu mẫu từ thư viện Sklearn
#
# ---------------------------------
# * Mã sinh viên:1821050766
# * Họ và tên:Trịnh Văn Rinh
# * Lớp:DCCTKM63B
# * Email:trinhrinh55@gmail.com

# %% [markdown]
# ## THỰC HÀNH 1
# ---
# **Yêu cầu 1.1: Học viên đọc dữ liệu dạng CSV lưu trong file Data_Titanic.csv với các tham số mặc định**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY!}
import pandas as pd
path_csv = "Data_Titanic.csv"

# %%
data = pd.read_csv(path_csv)

# %%
data

# %% [markdown]
# **Yêu cầu 1.2: Đọc dữ liệu từ file Data_Titanic.CSV vào 2 biến DataFrame tương ứng**
# 1. df_number: Chỉ chứa các cột dữ liệu số
# 2. df_object: Chỉ chứa các cột dữ liệu Object

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY!}
data.info()

# %%
#df_number = pd.DataFrame(data, columns = ["PassengerId", "Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"])
df_number = data.select_dtypes(include=["number"])

# %%
df_number
# Out:
#       PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0               1         0       3  22.0      1      0    7.2500
# 1               2         1       1  38.0      1      0   71.2833
# 2               3         1       3  26.0      0      0    7.9250
# 3               4         1       1  35.0      1      0   53.1000
# 4               5         0       3  35.0      0      0    8.0500
# ...           ...       ...     ...   ...    ...    ...       ...
# 1304         1305         0       3   NaN      0      0    8.0500
# 1305         1306         1       1  39.0      0      0  108.9000
# 1306         1307         0       3  38.5      0      0    7.2500
# 1307         1308         0       3   NaN      0      0    8.0500
# 1308         1309         0       3   NaN      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#df_object = pd.DataFrame(data, columns = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'])
df_object = data.select_dtypes(include=["object"])

# %%
df_object
# Out:
#                                                    Name     Sex  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171   NaN        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282   NaN        S
# ...

# %% [markdown]
# **Yêu cầu 1.3: Đọc dữ liệu nhiệt độ của 6 thành phố [Hà Nội, Vinh, Đà Nẵng, Nha Trang, TP Hồ Chí Minh, Cà Mau] từ file txt_Data_Temp.txt vào biến DataFrame tương ứng**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY!}
df = pd.read_csv("Data/txt_Data_Temp.txt",sep = " ",
                 names = ["Hà Nội", "Vinh", "Đà Nẵng", "Nha Trang", "TP Hồ Chí Minh", "Cà Mau"])

# %%
df
# Out:
#      Hà Nội   Vinh  Đà Nẵng  Nha Trang  TP Hồ Chí Minh  Cà Mau
# 0     25.65  24.79    24.01      25.06           25.48   24.97
# 1     25.31  24.21    24.02      24.93           25.16   24.83
# 2     25.05  23.73    23.89      24.79           24.80   24.55
# 3     24.79  23.36    23.83      24.84           24.74   24.48
# 4     24.59  23.05    23.69      24.82           24.80   24.38
# ..      ...    ...      ...        ...             ...     ...
# 187   26.56  24.92    24.10      26.11           25.56   26.43
# 188   25.69  24.77    23.76      25.97           25.23   25.88
# 189   24.81  24.47    23.40      25.86           25.05   25.29
# 190   23.97  24.22    22.95      25.74           24.92   24.87
# 191   22.84  23.99    22.59      25.50           24.77   24.57
#
# [192 rows x 6 columns]

# %% [markdown]
# ## THỰC HÀNH 2:
# ---
# Yêu cầu 2.1: Học viên đọc dữ liệu dạng excel lưu trong file excel_Data_Movies.xls theo từng sheet, sau đó nối các dataframe lại với nhau thành một DataFrame duy nhất df_movies

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY!}
path_ex = "Data\excel_Data_Movies.xls"

# %%
df_sheets1 = pd.read_excel(path_ex, sheet_name = 0)

# %%
df_sheets1
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df_sheets2 = pd.read_excel(path_ex, sheet_name = 1, skiprows = 3)

# %%
df_sheets2
# Out:
#                                   Title  Year  \
# 0                       102 Dalmatians   2000
# 1                              28 Days   2000
# 2                            3 Strikes   2000
# 3                             Aberdeen   2000
# 4                All the Pretty Horses   2000
# ...                                 ...   ...
# 2095          X-Men Origins: Wolverine   2009
# 2096                          Year One   2009
# 2097                   Youth in Revolt   2009
# 2098  ZMD: Zombies of Mass Destruction   2009
# 2099                        Zombieland   2009
#
#                                         Genres Language Country  \
# 0                      Adventure|Comedy|Family  English     USA
# 1                                 Comedy|Drama  English     USA
# 2                                       Comedy  English     USA
# 3                                        Drama  English      UK
# 4                        Drama|Romance|Western  English     USA
# ...

# %%
df_sheets3 = pd.read_excel(path_ex, sheet_name = 2, skiprows = 3, header = None)

# %%
df_sheets3
# Out:
#                                         0       1   \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                              2         3          4        5   \
# 0            Adventure|Biography|Drama|Thriller   English        USA        R
# 1                                         Drama   English        USA        R
# 2                          Comedy|Drama|Romance    German    Germany  Unrated
# ...

# %%
df_sheets3 = pd.read_excel(path_ex,
                           sheet_name = 2,
                           names = ['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
                                    'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
                                    'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
                                    'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
                                    'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
                                    'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
                                    'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
                           skiprows = 3,
                           header = None)
df_movies = pd.concat([df_sheets1, df_sheets2, df_sheets3])

# %%
df_movies
# Out:
#                                                   Title    Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                       Over the Hill to the Poorhouse   1920.0
# 2                                       The Big Parade   1925.0
# 3                                           Metropolis   1927.0
# 4                                        Pandora's Box   1929.0
# ...                                                 ...     ...
# 1599                           War & Peace                  NaN
# 1600                                 Wings                  NaN
# 1601                            Wolf Creek                  NaN
# 1602                     Wuthering Heights                  NaN
# 1603               Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0                             Drama|History|War       NaN        USA
# ...

# %% [markdown]
# ## THỰC HÀNH 3
# ---
# **Yêu cầu 3.1:** Học viên tìm hiểu tập dữ liệu mẫu nhận dạng các loại rượu ( Wine recognition dataset).
# 1. Cho biết bộ dữ liệu này lưu trữ dữ liệu gì?
# 2. Có bao nhiêu thuộc tính? bao nhiêu bản ghi?
# 3. Đọc dữ liệu từ dataset mẫu bào biến dataframe.
# 4. Hiển thị một số mẫu rượu trong tập dữ liệu

# %%
#{HỌC VIÊN VIẾT CODE Ở ĐÂY}
#1. bộ dữ liệu lưu trữ rượu vang
#2. có 13 thuộc tính, có 178 bản ghi
#3. 
from sklearn.datasets import load_wine
wine = load_wine()
df_wine = pd.DataFrame(wine.data, columns=wine.feature_names)

# %%
df_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df_wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#4. 
df_wine.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %% [markdown]
# **Yêu cầu 3.2:** Học viên tìm hiểu tập dữ liệu mẫu còn lại trong bộ Datasets của thư viện Sklearn:
# 1. Cho biết bộ dữ liệu này lưu trữ dữ liệu gì?
# 2. Có bao nhiêu thuộc tính? bao nhiêu bản ghi?
# 3. Tập dữ này dùng cho bài toán nào?

# %%
#1.Tập dữ liệu Diabetes Dataset
#{Học viên mô tả các tập dữ liệu của thư viện Sklearn vào đây!}
    #1.1 bộ dữ liệu lưu trữ về bệnh tiểu đường
    #1.2 có 10 thuộc tính, 442 bản ghi
    #1.3 tập dữ liệu dùng cho bài toán về xác định được những người có nguy cơ mắc bệnh tiểu đường

# %%
#2.Tập dữ liệu Digits Dataset
#{Học viên mô tả các tập dữ liệu của thư viện Sklearn vào đây!}
    #2.1 bộ dữ liệu lưu trữ chữ số
    #2.2 có 64 thuộc tính, có 1797 bản ghi
    #2.3 tập dữ liệu dùng cho bài toán về phân loại các tập dữ liệu số

# %%
#3.Tập dữ liệu Breast Cancer Wisconsin Dataset
#{Học viên mô tả các tập dữ liệu của thư viện Sklearn vào đây!}
    #3.1 bộ dữ ung thư vú 
    #3.2 có 30 thuộc tính, 569 bản ghi
    #3.3 tập dữ liệu dùng cho bài toán khả năng người bệnh có thể bị ung thư

# %%
#4. Tập dữ liệu linnerud dataset
    #4.1 bộ dữ liệu  linnerud vật lý
    #4.2 có 3 thuộc tính, 20 bản ghi
    #4.3 tập dữ liệu này phù hợp cho các tác vụ hồi quy nhiều lần
